# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/home/ayaz/Music/fileconversions-data-/datafiles/combined1.csv")
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.DataFrame(data)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.head(10))
# Out:
#    condition condition_cui                           label     label_cui  \
# 0  cataracts      C0086543   intraocular lens implantation  ['C0023311']
# 1  cataracts      C0086543             phacoemulsification  ['C0282545']
# 2  cataracts      C0086543                 senile cataract  ['C0036646']
# 3  cataracts      C0086543                     astigmatism  ['C0004106']
# 4  cataracts      C0086543             bilateral cataracts  ['C0521707']
# 5  cataracts      C0086543                          cancer  ['C0006826']
# 6  cataracts      C0086543      following cataract surgery  ['C3468053']
# 7  cataracts      C0086543                       mydriasis  ['C0026961']
# 8  cataracts      C0086543                            locs  ['C0041657']
# 9  cataracts      C0086543  bilateral age-related cataract  ['C2025430']
#
#    label_score                               label_semantic_types  label_ncts  \
# 0     4.293930                therapeutic or preventive procedure         310
# ...

# %%
df1=df[["condition","label_bucket","label","label_ncts"]].head(20)
print(df1)
# Out:
#     condition label_bucket                               label  label_ncts
# 0   cataracts     have_had       intraocular lens implantation         310
# 1   cataracts     have_had                 phacoemulsification         211
# 2   cataracts     have_had                     senile cataract         109
# 3   cataracts     have_had                         astigmatism         144
# 4   cataracts     have_had                 bilateral cataracts          91
# 5   cataracts     have_had                              cancer           8
# 6   cataracts     have_had          following cataract surgery          37
# 7   cataracts     have_had                           mydriasis          48
# 8   cataracts     have_had                                locs          33
# 9   cataracts     have_had      bilateral age-related cataract          27
# 10  cataracts     have_had                               glare          28
# ...

# %%
len(df)
# Out:
# 457

# %%
df.shape
# Out:
# (457, 9)

# %%
pd.set_option("display.max.columns", None)

# %%
df
# Out:
#      condition condition_cui                               label  \
# 0    cataracts      C0086543       intraocular lens implantation
# 1    cataracts      C0086543                 phacoemulsification
# 2    cataracts      C0086543                     senile cataract
# 3    cataracts      C0086543                         astigmatism
# 4    cataracts      C0086543                 bilateral cataracts
# 5    cataracts      C0086543                              cancer
# 6    cataracts      C0086543          following cataract surgery
# 7    cataracts      C0086543                           mydriasis
# 8    cataracts      C0086543                                locs
# 9    cataracts      C0086543      bilateral age-related cataract
# 10   cataracts      C0086543                               glare
# 11   cataracts      C0086543                          keratotomy
# 12   cataracts      C0086543                         keratometry
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
# condition               457 non-null object
# condition_cui           457 non-null object
# label                   457 non-null object
# label_cui               457 non-null object
# label_score             457 non-null float64
# label_semantic_types    457 non-null object
# label_ncts              457 non-null int64
# label_bucket            457 non-null object
# label_ncts_count        457 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 32.2+ KB

# %%
df.describe()
# Out:
#        label_score   label_ncts
# count   457.000000   457.000000
# mean      0.391897    29.737418
# std       1.744654    79.635167
# min       0.000046     0.000000
# 25%       0.033203     2.000000
# 50%       0.107393     8.000000
# 75%       0.297618    27.000000
# max      32.288549  1234.000000

# %%
df.describe(include=np.object)
# Out:
#                  condition condition_cui    label     label_cui  \
# count                  457           457      457           457
# unique                   7             7      429           428
# top     multiple sclerosis      C0026769  retinal  ['C0006826']
# freq                    80            80        3             4
#
#        label_semantic_types label_bucket label_ncts_count
# count                   457          457              457
# unique                   57            2              405
# top     disease or syndrome     have_had  ['NCT02964884']
# freq                     84          280               14

# %%
df["label"].value_counts()
# Out:
# retinal                         3
# cancer                          3
# diabetes                        3
# chronic disease                 2
# copd                            2
# angiography                     2
# lidocaine                       2
# ketorolac                       2
# calcium                         2
# insulin                         2
# body mass index                 2
# ace inhibitor                   2
# aspirin                         2
# atenolol                        2
# atorvastatin                    2
# fatigue                         2
# anxiety                         2
# methylprednisolone              2
# brain mri                       2
# ct scan                         2
# corticosteroids                 2
# hydroxychloroquine              2
# interferon                      2
# antihypertensive drugs          2
# hypertension                    2
# immunomodulation therapy        1
# myelopathies                    1
# ...

# %%
df["label_bucket"].value_counts()
# Out:
# have_had       280
# looking_for    177
# Name: label_bucket, dtype: int64

# %%
revenues = pd.Series( [4200, 8000, 6500], index=["Amsterdam", "Toronto", "Tokyo"] )

# %%
revenues.values
# Out:
# array([4200, 8000, 6500])

# %%
revenues.index
# Out:
# Index(['Amsterdam', 'Toronto', 'Tokyo'], dtype='object')
